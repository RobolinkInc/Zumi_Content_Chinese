# %% [markdown]
# <img src="../Data/images/ZumiHeader.png" width=700>

# %% [markdown]
# # 基本駕駛指令(Basic Drive Commands)
# <font size =3>歡迎來到Zumi的第一課！ 🎉在您開始使用Zumi進行機器學習 (Machine Learning) 之前，她需要您的幫助以學習如何前進，後退，向左和向右。 在本課程稍後的部分，您將學習到如何製作自定義遙控器。 </font>
#
#
# ###導入庫(Import libraries)
#
# <font size =3>使用Zumi運行任何代碼的第一步都是導入庫(Import libraries)。 換句話說，此單元導入了Zumi的所有必要功能，例如驅動命令，攝像頭或屏幕。 如果您不運行此單元格，程序的剩餘部分都將會無法正常運行！ 除非您需重新啟動Jupyter Notebook，否則您只需要在每一個課程中一次運行以下的單元格即可。</font>

# %%
from zumi.zumi import Zumi
import time

zumi = Zumi()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-62e4af31ce0f> in <module>()
# ----> 1 from zumi.zumi import Zumi
#       2 import time
#       3
#       4 zumi = Zumi()
#
# ModuleNotFoundError: No module named 'zumi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 駕駛命令(Drive Commands)
#
# <font size =3> Zumi使用函數來進行驅動。 在本課程中，我們將更深入地介紹將會用到的函數，它們的功能是什麼以及如何使用它們來創建遙控器。 </font>
#
# ### 什麼是函數(What are functions?)
# <font size =3> 要讓Zumi行駛，我們需要使用一些指令。 將函數視為一組組編程可以有效提高程式的效率。我們可以選擇**輸入(inputs**)或**輸出(outputs)**的指令來控制Zumi.</font>
# <img src="../Data/images/function.jpg" width=700>
#
# ### Zumi函數(Zumi functions)
# <font size=3>以下是基本行駛指令列表:
#
# * <font face="Courier">forward()</font>: Zumi將以40速度向前移動1秒
# * <font face="Courier">reverse()</font>: Zumi將以相反的方向40速度向前移動1秒
# * <font face="Courier">turn_left()</font>: 向左旋轉90度
# * <font face="Courier">turn_right()</font>: 向右旋轉90度
#
# </font>
#
# ### 如何呼叫函數(How to call functions)
# <font size =3> 在計算機科學中，呼叫任何東西基本上都是要求它運行。 函數在使用時必須設有一個對象名稱(Object name),在這種情況下為就是<font face="Courier">zumi</font>。
#
# <img src="../Data/images/zumi_forward.jpg" width=700>
#
# 以下的例子是使用 <font face="Courier">forward()</font>函數. Zumi將向前行駛1秒,因此請確保你有足夠的空間供它行駛！</font>

# %%
zumi.forward()

# %% [markdown]
# ```
# # 此內容會顯示為程式碼
# ```
#
# <font size =3>  現在嘗試反方向... </font>

# %%
# TODO Write code so Zumi reverses for 1 second
zumi.reverse()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-06679f095601> in <module>
#       1 # TODO Write code so Zumi reverses for 1 second
# ----> 2 zumi.reverse()
#
# NameError: name 'zumi' is not defined

# %% [markdown]
# <font size=3>讓我們看一下接下來的兩個功能. 呼叫 <font face="Courier">turn_left()</font> and <font face="Courier">turn_right()</font> 將令ｚumi向左或向右旋轉。
#
# 測試以下的編程，看看會發生什麼事情。如果你想在指令之間保留一些時間，加入<font face="Courier">time.sleep(seconds)</font>將編程延遲到指定的秒數。
# 運行以下的編程以查看它的運作原理,並嘗試加入更多指令來豐富整個程式。</font>

# %%
zumi.forward() # Drive forward for 1 second then stop
time.sleep(2) # Wait 2 seconds
zumi.turn_right() # Turn right 90 degrees
# Add more code here!

# %% [markdown]
# ### 參數(Parameters)
# <font size =3>  在此刻， 您可能需要更改Zumi向前行駛的持續時間，方向和速度。 某些函數會充許你輸**參數(parameters)**， 這些都是額外的信息，可讓您根據需要進一步來自定義功能。 現時 <font face="Courier">forward()</font> 是一個默認的速度,時間跟方向，但你能改變參數(parameters)來改變Zumi的速度,方向,行駛時間等等...
#
# 我們將先跳過改變Zumi的行駛方向，因為它需要對Zumi的感應器有更多的理解，但您可以通過在函數調用中定義它們來更改速度和持續時間。 在以下的單元格中，編程已經把速度修改為30並行駛2秒。請確保你已經預留足夠的空間給Zumi！</font>

# %%
zumi.forward(speed=30, duration=2)

# %% [markdown]
# <font size =3> 您可以為反向做同樣的事情。 改變速度及運行時間 <font face="Courier">reverse()</font>: </font>

# %%
# TODO Modify reverse() to go at speed 20 for 3 seconds

# %% [markdown]
# ### 角度(Degrees)
#
# <font size=3>函數 <font face="Courier">turn_left()</font> 和 <font face="Courier">turn_right()</font> 也有可以改變的參數。 默認的角度為90度,但這個數字是可以改變的。
# 以下的編程是將Zumi由向右旋轉90度改為45度：</font>

# %%
zumi.turn_right(45)

# %% [markdown]
# <font size=3> 通過測試不同的角度來嘗試轉彎的精度。 如有需要，請使用此圖作為參考！ Zumi並不完美，因此Zumi停止的實際角度可能會偏離一到兩個度。</font>
#
# <img src="../Data/images/zumi_angle.jpg" width=700>
#
# <font size=3>**注釋**: 這裡有另一個隱藏的默認參數在 <font face="Courier">turn_right()</font> 及 <font face="Courier">turn_left()</font>中。 當你呼叫 <font face="Courier">turn_left(45)</font>, 實際上你是在呼叫 <font face="Courier">turn_left(desired_angle=45, duration=1)</font>. 持續時間(duration)是決定Zumi需要多少時間完成整個轉向。一秒足夠用於較小的轉彎，但如果你需轉彎135度呢？你便需要提高Zumi所需的轉彎時間。
# <font face="Courier">zumi.turn_left(120, 1.5)</font>
#
# 由於Zumi正在轉120度，你必需增加它的持續時間否則Zumi將不能完成整個轉彎。您可能需要調整第二個參數，因為每個Zumi都是獨特的。 請使用下面的單元格進行試駕和轉彎。 </font>

# %%
# Test some code here

# %% [markdown]
# ## Recalibrating(重新校準)
# <font size=3> 如果您發現Zumi不能以直線行駛，則可能需要重新校準。出現這個情況的原因有可能是因為Zumi過熱了。請不要拿起Zumi，而是放置它在平面上休息以降低溫度。</font>

# %%
zumi.mpu.calibrate_MPU()

# %% [markdown]
# <font size=3> 現在您已經了解了基礎知識！請使用下面的單元格來測試更多編程。對於這個額外挑戰，請使用一些您隨手便可以拿到的材料來構建簡單的障礙物路線，並編寫一些代碼讓Zumi順利通過它。在下一課中，您將學習如何將驅動器命令與if語句(if-statements)組合在一起以構成自己的遙控器。</font>

# %%
# Write some more code here!

# %% [markdown]
# <hr>
#
# # Extension Activities(廷伸活動) <br>
#
# <img src="../Data/images/engineering_extension.png" width=75 align="left">
#
# ###  Bridge Challenge(橋樑挑戰) <br> <br>
# <font size=3> 隨意選擇一些物件來築起一座橋。但請確保您使用的物料是相對平坦跟寬的，這樣Zumi會比較好行駛並不會卡住車輛。冰棒棍是一個不錯的選擇，我們能透過改變冰棒棍的數目而改變傾斜度，高度，寬度等變數。建造完橋之後，請查看(a) Zumi是否能過橋到終點(b)橋是否可以支撐Zumi的重量。對於再進一步的挑戰，可以嘗試在Zumi加上一些負載物件。</font>
#
# <img src="../Data/images/math_extension.jpg" width=70 align="left">
#
# ### Calculate Speed (計算速度) <br> <br>
# <font size=3> 記錄您的Zumi在一定距離的行駛時間或需時多久才能到達目的距離。接著，利用算式 d=st 來計算速率。 然後，以圖形方式顯示結果並分析結果。
# 最後，嘗試在Zumi加上負載物件以探究對Zumi速度的影響。
# 注: d = distance traveled(距離) , s = speed(速度) , t = time elapsed(時間) </font>
